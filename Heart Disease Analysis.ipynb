# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # Heart Disease EDA - Age (DistPlot)

# %%
sns.displot(df['Age'])

# %%
sns.displot(df['Age'], kde = True)

# %%
sns.distplot(df['Age'], kde=False, hist= True)
# Out:
# C:\Users\akuld\AppData\Local\Temp\ipykernel_16764\1041589920.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde=False, hist= True)
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Age'], bins= 10)
# Out:
# C:\Users\akuld\AppData\Local\Temp\ipykernel_16764\1786075524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], bins= 10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'], kde= True, color = 'blue')
# Out:
# C:\Users\akuld\AppData\Local\Temp\ipykernel_16764\2176837848.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], kde= True, color = 'blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'], kde= True, color='blue')
# Out:
# C:\Users\akuld\AppData\Local\Temp\ipykernel_16764\1500552277.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'], kde= True, color='blue')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'], kde = True, color='blue' )
# Out:
# C:\Users\akuld\AppData\Local\Temp\ipykernel_16764\128539759.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'], kde = True, color='blue' )
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df['Oldpeak'], kde=True, color='blue')
# Out:
# C:\Users\akuld\AppData\Local\Temp\ipykernel_16764\4149283870.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Oldpeak'], kde=True, color='blue')
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# #   Categorical Columns (Pie Charts)

# %%
df.groupby('Sex').size().plot(kind='pie', autopct = '%.1f', figsize= (6,6), title='Sex Distribution')
# Out:
# <Axes: title={'center': 'Sex Distribution'}>

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct='%.1f', figsize=(6,6), title='Chest Pain Type Distribution')
# Out:
# <Axes: title={'center': 'Chest Pain Type Distribution'}>

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct='%.1f', figsize=(6,6), title='ST_Slope Distribution')
# Out:
# <Axes: title={'center': 'ST_Slope Distribution'}>

# %% [markdown]
# df.groupby('RestingECG').size().plot(kind = 'pie', autopct='%.1f', figsize=(6,6), title='RestingECG Distribution')

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct='%.1f', figsize=(6,6), title='HeartDisease Distribution')
# Out:
# <Axes: title={'center': 'HeartDisease Distribution'}>

# %% [markdown]
# #  ViolinPlot

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(y ='Sex', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y ='Age', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y ='RestingBP', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(y ='Cholesterol', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(y ='ST_Slope', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ST_Slope'>

# %%
sns.violinplot(y ='Oldpeak', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Oldpeak'>

# %%
sns.violinplot(y ='ExerciseAngina', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ExerciseAngina'>

# %%
sns.violinplot(y ='MaxHR', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='MaxHR'>

# %%
sns.violinplot(y ='ChestPainType', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ChestPainType'>

# %%
sns.violinplot(y ='FastingBS', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='FastingBS'>

# %%
sns.violinplot(y ='RestingECG', x ='HeartDisease', data= df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingECG'>

# %% [markdown]
# # Correlation (HeatMap)
#
# Heat Map are used to find Correlation between different Columns

# %%
# Deleted columns which are not in int data type by using
#del df['column name']
del df['RestingECG']
del df['ST_Slope']

# %%
df.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Correlation - (JointPlot)

# %%
sns.jointplot(x = 'Age' ,  y ='MaxHR', data = df, kind = 'hex')

# %%
sns.jointplot(x = 'Age' ,  y ='MaxHR', data = df, kind = 'reg')
# Making An Regression Line

# %%
sns.jointplot(x = 'Cholesterol' ,  y ='Oldpeak', data = df, kind = 'hex')

# %%
sns.jointplot(x = 'Cholesterol' ,  y ='FastingBS', data = df,  kind = 'reg')

# %%
sns.jointplot(x = 'HeartDisease' ,  y ='MaxHR', data = df,  kind = 'reg')

# %%
sns.jointplot(x = 'Cholesterol' ,  y ='MaxHR', data = df,  kind = 'reg')

# %% [markdown]
# # Correlation Pair Plot
#
# It plot all Correlation Graph

# %%
sns.pairplot(df , kind='reg')
